# %%
import json
import requests

while True:

    ticker_url = 'https://api.coinmarketcap.com/v2/ticker/?structure=array'

    limit = 100
    start = 1
    sort = 'rank'
    convert = 'USD'

    choice = input("Do you want to enter any custom parameters? (y/n): ")

    if choice == 'y':
        limit = input('What is the custom limit?: ')
        start = input('What is the custom start number?: ')
        sort = input('What do you want to sort by?: ')
        convert = input('What is your local currency?: ')

    ticker_url += '&limit=' + str(limit) + '&sort=' + sort + '&start=' + str(start) + '&convert=' + convert

    request = requests.get(ticker_url)
    results = request.json()

    # print(json.dumps(results, sort_keys=True, indent=4))

    data = results['data']

    print()
    for currency in data:
        rank = currency['rank']
        name = currency['name']
        symbol = currency['symbol']

        circulating_supply = int(currency['circulating_supply'])
        total_supply = int(currency['total_supply'])

        quotes = currency['quotes'][convert]
        market_cap = quotes['market_cap']
        hour_change = quotes['percent_change_1h']
        day_change = quotes['percent_change_24h']
        week_change = quotes['percent_change_7d']
        price = quotes['price']
        volume = quotes['volume_24h']

        volume_string = '{:,}'.format(volume)
        market_cap_string = '{:,}'.format(market_cap)
        circulating_supply_string = '{:,}'.format(circulating_supply)
        total_supply_string = '{:,}'.format(total_supply)

        print(str(rank) + ': ' + name + ' (' + symbol + ')')
        print('Market cap: \t\t$' + market_cap_string)
        print('Price: \t\t\t$' + str(price))
        print('24h Volume: \t\t$' + volume_string)
        print('Hour change: \t\t' + str(hour_change) + '%')
        print('Day change: \t\t' + str(day_change) + '%')
        print('Week change: \t\t' + str(week_change) + '%')
        print('Total supply: \t\t' + total_supply_string)
        print('Circulating supply: \t' + circulating_supply_string)
        print('Percentage of coins in circulation: ' + str(int(circulating_supply / total_supply * 100)))
        print()

    choice = input('Again? (y/n): ')

    if choice == 'n':
        break
# Out:
# Do you want to enter any custom parameters? (y/n): y
# What is the custom limit?: 200
# What is the custom start number?: 3
# What do you want to sort by?: rank
# What is your local currency?: INR
#
# 3: XRP (XRP)
# Market cap: 		$892,125,998,671.0
# Price: 			$20.7999828676
# 24h Volume: 		$65,023,208,437.53903
# Hour change: 		-0.32%
# Day change: 		-1.48%
# Week change: 		-6.32%
# Total supply: 		99,991,376,954
# Circulating supply: 	42,890,708,341
# Percentage of coins in circulation: 42
#
# 4: Bitcoin Cash (BCH)
# Market cap: 		$430,845,267,373.0
# Price: 			$24006.6344163767
# 24h Volume: 		$133,606,338,753.92375
# Hour change: 		-0.09%
# Day change: 		0.18%
# Week change: 		-0.14%
# Total supply: 		17,946,925
# Circulating supply: 	17,946,925
# Percentage of coins in circulation: 100
#
# 5: Litecoin (LTC)
# Market cap: 		$368,818,705,224.0
# Price: 			$5850.9618485311
# 24h Volume: 		$203,961,314,033.5655
# Hour change: 		-0.95%
# Day change: 		-3.19%
# Week change: 		-10.48%
# Total supply: 		63,035,568
# Circulating supply: 	63,035,568
# Percentage of coins in circulation: 100
#
# 6: Binance Coin (BNB)
# Market cap: 		$317,514,983,521.0
# Price: 			$2041.4150292702
# 24h Volume: 		$16,584,785,825.340775
# Hour change: 		-0.53%
# Day change: 		-3.41%
# Week change: 		0.34%
# Total supply: 		187,536,713
# Circulating supply: 	155,536,713
# Percentage of coins in circulation: 82
#
# 7: Tether (USDT)
# Market cap: 		$287,658,423,311.0
# Price: 			$71.1540356194
# 24h Volume: 		$1,289,508,491,256.7922
# Hour change: 		-0.01%
# Day change: 		-0.14%
# Week change: 		-0.24%
# Total supply: 		4,095,057,493
# Circulating supply: 	4,042,756,265
# Percentage of coins in circulation: 98
#
# 8: EOS (EOS)
# Market cap: 		$265,050,582,373.0
# Price: 			$285.7913898817
# 24h Volume: 		$105,762,063,029.06122
# Hour change: 		-0.57%
# Day change: 		-0.62%
# Week change: 		-4.95%
# Total supply: 		1,024,126,764
# Circulating supply: 	927,426,759
# Percentage of coins in circulation: 90
#
# 9: Bitcoin SV (BSV)
# Market cap: 		$187,864,663,361.0
# Price: 			$10521.6921470728
# 24h Volume: 		$26,948,484,963.70903
# Hour change: 		1.26%
# Day change: 		4.75%
# Week change: 		0.22%
# Total supply: 		17,854,986
# Circulating supply: 	17,854,986
# Percentage of coins in circulation: 100
#
# 10: Stellar (XLM)
# Market cap: 		$103,004,120,757.0
# Price: 			$5.2464326635
# 24h Volume: 		$4,982,443,987.113554
# Hour change: 		-0.42%
# Day change: 		-0.57%
# Week change: 		-5.95%
# Total supply: 		105,243,009,213
# Circulating supply: 	19,633,173,122
# Percentage of coins in circulation: 18
#
# 11: Monero (XMR)
# Market cap: 		$102,146,287,867.0
# Price: 			$5954.6023430415
# 24h Volume: 		$6,087,041,221.526223
# Hour change: 		-1.01%
# Day change: 		-5.09%
# Week change: 		-10.72%
# Total supply: 		17,154,175
# Circulating supply: 	17,154,175
# Percentage of coins in circulation: 100
#
# 12: Cardano (ADA)
# Market cap: 		$95,786,161,361.0
# Price: 			$3.6944459738
# 24h Volume: 		$3,706,613,715.193281
# Hour change: 		0.54%
# Day change: 		1.97%
# Week change: 		-1.54%
# Total supply: 		31,112,483,745
# Circulating supply: 	25,927,070,538
# Percentage of coins in circulation: 83
#
# 13: TRON (TRX)
# Market cap: 		$94,608,535,523.0
# Price: 			$1.4188001724
# 24h Volume: 		$32,361,116,747.42799
# Hour change: 		-0.59%
# Day change: 		-1.72%
# Week change: 		-8.79%
# Total supply: 		99,281,283,754
# Circulating supply: 	66,682,072,191
# Percentage of coins in circulation: 67
#
# 14: UNUS SED LEO (LEO)
# Market cap: 		$90,423,833,047.0
# Price: 			$90.4691677896
# 24h Volume: 		$484,966,883.31826663
# Hour change: 		-0.05%
# Day change: 		0.54%
# Week change: 		0.51%
# Total supply: 		999,498,893
# Circulating supply: 	999,498,893
# Percentage of coins in circulation: 100
#
# 15: Dash (DASH)
# Market cap: 		$64,162,146,295.0
# Price: 			$7145.1260851563
# 24h Volume: 		$12,561,733,409.122217
# Hour change: 		0.13%
# Day change: 		-2.17%
# Week change: 		-6.92%
# Total supply: 		8,979,848
# Circulating supply: 	8,979,848
# Percentage of coins in circulation: 100
#
# 16: Chainlink (LINK)
# Market cap: 		$62,020,876,582.0
# Price: 			$177.2025045214
# 24h Volume: 		$7,637,467,374.213214
# Hour change: 		0.79%
# Day change: 		5.89%
# Week change: 		3.01%
# Total supply: 		1,000,000,000
# Circulating supply: 	350,000,000
# Percentage of coins in circulation: 35
#
# 17: Tezos (XTZ)
# Market cap: 		$57,507,628,715.0
# Price: 			$87.083474676
# 24h Volume: 		$655,001,942.1286421
# Hour change: 		-1.11%
# Day change: 		-7.42%
# Week change: 		-14.59%
# Total supply: 		801,312,599
# Circulating supply: 	660,373,612
# Percentage of coins in circulation: 82
#
# 18: NEO (NEO)
# Market cap: 		$51,157,626,666.0
# Price: 			$725.2406361319
# 24h Volume: 		$16,728,882,617.224083
# Hour change: 		-0.87%
# Day change: 		-1.83%
# Week change: 		-10.51%
# Total supply: 		100,000,000
# Circulating supply: 	70,538,831
# Percentage of coins in circulation: 70
#
# 19: IOTA (MIOTA)
# Market cap: 		$50,435,571,596.0
# Price: 			$18.1453578342
# 24h Volume: 		$504,826,519.47096866
# Hour change: 		0.84%
# Day change: 		-0.0%
# Week change: 		-8.98%
# Total supply: 		2,779,530,283
# Circulating supply: 	2,779,530,283
# Percentage of coins in circulation: 100
#
# 20: Ethereum Classic (ETC)
# Market cap: 		$47,176,163,404.0
# Price: 			$418.6021461158
# 24h Volume: 		$40,570,682,146.40271
# Hour change: 		-1.22%
# Day change: 		1.39%
# Week change: 		-0.77%
# Total supply: 		112,699,287
# Circulating supply: 	112,699,287
# Percentage of coins in circulation: 100
#
# 21: Cosmos (ATOM)
# Market cap: 		$42,654,362,627.0
# Price: 			$223.6861490193
# 24h Volume: 		$9,549,202,482.704123
# Hour change: 		-0.53%
# Day change: 		-2.44%
# Week change: 		-11.28%
# Total supply: 		237,928,231
# Circulating supply: 	190,688,439
# Percentage of coins in circulation: 80
#
# 22: NEM (XEM)
# Market cap: 		$35,579,974,760.0
# Price: 			$3.9533305293
# 24h Volume: 		$2,258,520,500.2655807
# Hour change: 		-0.42%
# Day change: 		0.0%
# Week change: 		-13.12%
# Total supply: 		8,999,999,999
# Circulating supply: 	8,999,999,999
# Percentage of coins in circulation: 100
#
# 23: Maker (MKR)
# Market cap: 		$34,055,360,074.0
# Price: 			$34055.3600736045
# 24h Volume: 		$157,556,365.52167624
# Hour change: 		-0.48%
# Day change: 		-0.23%
# Week change: 		-15.27%
# Total supply: 		1,000,000
# Circulating supply: 	1,000,000
# Percentage of coins in circulation: 100
#
# 24: Ontology (ONT)
# Market cap: 		$32,472,271,478.0
# Price: 			$60.8944366781
# 24h Volume: 		$4,082,508,361.222963
# Hour change: 		-0.5%
# Day change: 		0.19%
# Week change: 		-9.83%
# Total supply: 		1,000,000,000
# Circulating supply: 	533,255,142
# Percentage of coins in circulation: 53
#
# 25: USD Coin (USDC)
# Market cap: 		$30,119,214,074.0
# Price: 			$71.5598416938
# 24h Volume: 		$8,349,844,807.168476
# Hour change: 		0.06%
# Day change: 		-0.1%
# Week change: 		0.04%
# Total supply: 		423,197,329
# Circulating supply: 	420,895,482
# Percentage of coins in circulation: 99
#
# 26: Crypto.com Chain (CRO)
# Market cap: 		$29,495,970,639.0
# Price: 			$3.2848296822
# 24h Volume: 		$951,815,663.6144705
# Hour change: 		-0.79%
# Day change: 		-4.33%
# Week change: 		-9.89%
# Total supply: 		100,000,000,000
# Circulating supply: 	8,979,452,055
# Percentage of coins in circulation: 8
#
# 27: Zcash (ZEC)
# Market cap: 		$27,902,486,426.0
# Price: 			$3880.7925953358
# 24h Volume: 		$7,875,550,275.628505
# Hour change: 		-0.64%
# Day change: 		-2.25%
# Week change: 		-12.57%
# Total supply: 		7,189,894
# Circulating supply: 	7,189,894
# Percentage of coins in circulation: 100
#
# 28: INO COIN (INO)
# Market cap: 		$27,276,281,722.0
# Price: 			$151.5322213851
# 24h Volume: 		$1,111,573.5323556906
# Hour change: 		-0.55%
# Day change: 		-1.75%
# Week change: 		-3.14%
# Total supply: 		1,000,000,000
# Circulating supply: 	180,003,180
# Percentage of coins in circulation: 18
#
# 29: V Systems (VSYS)
# Market cap: 		$26,907,925,935.0
# Price: 			$15.1163915524
# 24h Volume: 		$1,125,741,736.7223144
# Hour change: 		-0.53%
# Day change: 		-4.45%
# Week change: 		0.12%
# Total supply: 		3,684,908,011
# Circulating supply: 	1,780,049,547
# Percentage of coins in circulation: 48
#
# 30: Dogecoin (DOGE)
# Market cap: 		$24,186,600,141.0
# Price: 			$0.2002638017
# 24h Volume: 		$2,299,149,405.6852636
# Hour change: 		-0.12%
# Day change: 		-0.71%
# Week change: 		-5.76%
# Total supply: 		120,773,699,189
# Circulating supply: 	120,773,699,189
# Percentage of coins in circulation: 100
#
# 31: Bitcoin Gold (BTG)
# Market cap: 		$19,701,582,399.0
# Price: 			$1124.9096924973
# 24h Volume: 		$2,053,655,998.2259333
# Hour change: 		0.31%
# Day change: 		7.92%
# Week change: 		-7.52%
# Total supply: 		17,513,924
# Circulating supply: 	17,513,924
# Percentage of coins in circulation: 100
#
# 32: Decred (DCR)
# Market cap: 		$19,287,854,393.0
# Price: 			$1884.8213181523
# 24h Volume: 		$192,470,989.78052056
# Hour change: 		-0.1%
# Day change: 		-0.17%
# Week change: 		-16.38%
# Total supply: 		10,233,254
# Circulating supply: 	10,233,254
# Percentage of coins in circulation: 100
#
# 33: VeChain (VET)
# Market cap: 		$19,052,362,893.0
# Price: 			$0.3435660266
# 24h Volume: 		$2,155,119,780.7155375
# Hour change: 		-0.11%
# Day change: 		-1.57%
# Week change: 		-5.46%
# Total supply: 		86,712,634,466
# Circulating supply: 	55,454,734,800
# Percentage of coins in circulation: 63
#
# 34: Huobi Token (HT)
# Market cap: 		$17,856,340,056.0
# Price: 			$357.1253726089
# 24h Volume: 		$4,573,222,143.410641
# Hour change: 		-0.09%
# Day change: 		-0.16%
# Week change: 		2.19%
# Total supply: 		500,000,000
# Circulating supply: 	50,000,200
# Percentage of coins in circulation: 10
#
# 35: Qtum (QTUM)
# Market cap: 		$17,706,920,808.0
# Price: 			$184.5591652089
# 24h Volume: 		$11,760,918,330.31122
# Hour change: 		-0.67%
# Day change: 		-0.75%
# Week change: 		-11.56%
# Total supply: 		101,691,724
# Circulating supply: 	95,941,704
# Percentage of coins in circulation: 94
#
# 36: HedgeTrade (HEDG)
# Market cap: 		$17,680,267,298.0
# Price: 			$61.3060841659
# 24h Volume: 		$48,284,836.65706093
# Hour change: 		1.95%
# Day change: 		0.16%
# Week change: 		-6.47%
# Total supply: 		1,000,000,000
# Circulating supply: 	288,393,355
# Percentage of coins in circulation: 28
#
# 37: Basic Attention Token (BAT)
# Market cap: 		$17,203,434,090.0
# Price: 			$13.4746535487
# 24h Volume: 		$2,369,751,705.8428264
# Hour change: 		-0.64%
# Day change: 		-6.51%
# Week change: 		-14.88%
# Total supply: 		1,500,000,000
# Circulating supply: 	1,276,725,522
# Percentage of coins in circulation: 85
#
# 38: Egretia (EGT)
# Market cap: 		$14,167,573,175.0
# Price: 			$3.3591292883
# 24h Volume: 		$1,930,298,563.7302012
# Hour change: 		0.42%
# Day change: 		-3.16%
# Week change: 		2.17%
# Total supply: 		8,000,000,000
# Circulating supply: 	4,217,632,594
# Percentage of coins in circulation: 52
#
# 39: TrueUSD (TUSD)
# Market cap: 		$14,083,713,861.0
# Price: 			$71.5552683926
# 24h Volume: 		$19,194,910,235.36127
# Hour change: 		0.13%
# Day change: 		-0.1%
# Week change: 		0.17%
# Total supply: 		196,822,878
# Circulating supply: 	196,822,878
# Percentage of coins in circulation: 100
#
# 40: Paxos Standard Token (PAX)
# Market cap: 		$13,921,077,420.0
# Price: 			$71.5693742693
# 24h Volume: 		$12,561,521,877.770033
# Hour change: 		0.03%
# Day change: 		-0.13%
# Week change: 		0.26%
# Total supply: 		196,354,832
# Circulating supply: 	194,511,655
# Percentage of coins in circulation: 99
#
# 41: OmiseGO (OMG)
# Market cap: 		$13,122,527,268.0
# Price: 			$93.5683268941
# 24h Volume: 		$3,553,833,600.7033806
# Hour change: 		-0.85%
# Day change: 		-3.25%
# Week change: 		-10.44%
# Total supply: 		140,245,398
# Circulating supply: 	140,245,398
# Percentage of coins in circulation: 100
#
# 42: PLATINCOIN (PLC)
# Market cap: 		$11,655,088,948.0
# Price: 			$2330.5176605259
# 24h Volume: 		$227,485,125.35389215
# Hour change: 		0.25%
# Day change: 		-18.77%
# Week change: 		-17.2%
# Total supply: 		600,023,027
# Circulating supply: 	5,001,073
# Percentage of coins in circulation: 0
#
# 43: ThoreCoin (THR)
# Market cap: 		$11,099,958,986.0
# Price: 			$128047.8535470765
# 24h Volume: 		$10,747,782.66360175
# Hour change: 		-0.92%
# Day change: 		-4.83%
# Week change: 		-10.41%
# Total supply: 		100,000
# Circulating supply: 	86,686
# Percentage of coins in circulation: 86
#
# 44: KuCoin Shares (KCS)
# Market cap: 		$10,893,431,942.0
# Price: 			$122.644544559
# 24h Volume: 		$1,580,456,418.4139836
# Hour change: 		-0.31%
# Day change: 		0.28%
# Week change: 		-4.81%
# Total supply: 		178,821,170
# Circulating supply: 	88,821,170
# Percentage of coins in circulation: 49
#
# 45: Ravencoin (RVN)
# Market cap: 		$10,798,977,837.0
# Price: 			$2.5744952645
# 24h Volume: 		$872,488,248.385252
# Hour change: 		-1.46%
# Day change: 		-1.17%
# Week change: 		-8.89%
# Total supply: 		4,194,600,000
# Circulating supply: 	4,194,600,000
# Percentage of coins in circulation: 100
#
# 46: Lisk (LSK)
# Market cap: 		$10,289,304,339.0
# Price: 			$86.2345828219
# 24h Volume: 		$179,363,586.7880131
# Hour change: 		0.14%
# Day change: 		-0.26%
# Week change: 		-17.9%
# Total supply: 		134,414,023
# Circulating supply: 	119,317,610
# Percentage of coins in circulation: 88
#
# 47: Bitcoin Diamond (BCD)
# Market cap: 		$10,260,622,267.0
# Price: 			$55.0188365334
# 24h Volume: 		$650,189,801.585764
# Hour change: 		-0.61%
# Day change: 		-0.14%
# Week change: 		-3.65%
# Total supply: 		189,492,898
# Circulating supply: 	186,492,898
# Percentage of coins in circulation: 98
#
# 48: BitTorrent (BTT)
# Market cap: 		$10,219,020,645.0
# Price: 			$0.0481764532
# 24h Volume: 		$2,200,462,314.0439386
# Hour change: 		-0.54%
# Day change: 		0.97%
# Week change: 		-12.67%
# Total supply: 		990,000,000,000
# Circulating supply: 	212,116,500,000
# Percentage of coins in circulation: 21
#
# 49: EDUCare (EKT)
# Market cap: 		$9,944,838,205.0
# Price: 			$11.395422162
# 24h Volume: 		$516,164,242.09953773
# Hour change: 		-1.87%
# Day change: 		5.36%
# Week change: 		15.63%
# Total supply: 		1,000,000,000
# Circulating supply: 	872,704,676
# Percentage of coins in circulation: 87
#
# 50: Nano (NANO)
# Market cap: 		$9,919,863,791.0
# Price: 			$74.4464582278
# 24h Volume: 		$192,270,912.54637706
# Hour change: 		-0.32%
# Day change: 		-1.68%
# Week change: 		-5.43%
# Total supply: 		133,248,297
# Circulating supply: 	133,248,297
# Percentage of coins in circulation: 100
#
# 51: Energi (NRG)
# Market cap: 		$9,460,494,165.0
# Price: 			$483.5510893595
# 24h Volume: 		$57,848,441.00847852
# Hour change: 		-0.8%
# Day change: 		-3.59%
# Week change: 		-3.24%
# Total supply: 		19,564,608
# Circulating supply: 	19,564,622
# Percentage of coins in circulation: 100
#
# 52: Waves (WAVES)
# Market cap: 		$9,073,268,879.0
# Price: 			$90.7326887865
# 24h Volume: 		$899,999,847.1441517
# Hour change: 		-0.26%
# Day change: 		-1.08%
# Week change: 		-5.35%
# Total supply: 		100,000,000
# Circulating supply: 	100,000,000
# Percentage of coins in circulation: 100
#
# 53: Holo (HOT)
# Market cap: 		$8,812,309,003.0
# Price: 			$0.0661512375
# 24h Volume: 		$447,970,570.58136594
# Hour change: 		-1.37%
# Day change: 		-3.72%
# Week change: 		-4.58%
# Total supply: 		177,619,433,541
# Circulating supply: 	133,214,575,156
# Percentage of coins in circulation: 75
#
# 54: Lambda (LAMB)
# Market cap: 		$8,684,710,601.0
# Price: 			$14.0063218953
# 24h Volume: 		$2,999,864,333.4421988
# Hour change: 		-0.4%
# Day change: 		1.11%
# Week change: 		-1.19%
# Total supply: 		6,000,000,000
# Circulating supply: 	620,056,476
# Percentage of coins in circulation: 10
#
# 55: Aurora (AOA)
# Market cap: 		$8,563,380,053.0
# Price: 			$1.3089189721
# 24h Volume: 		$305,531,743.1308387
# Hour change: 		2.19%
# Day change: 		1.75%
# Week change: 		0.47%
# Total supply: 		10,000,000,000
# Circulating supply: 	6,542,330,148
# Percentage of coins in circulation: 65
#
# 56: Augur (REP)
# Market cap: 		$8,333,608,159.0
# Price: 			$757.60074171
# 24h Volume: 		$479,749,066.9159407
# Hour change: 		-0.61%
# Day change: 		-1.6%
# Week change: 		-5.25%
# Total supply: 		11,000,000
# Circulating supply: 	11,000,000
# Percentage of coins in circulation: 100
#
# 57: BitShares (BTS)
# Market cap: 		$8,311,966,384.0
# Price: 			$3.0340183692
# 24h Volume: 		$241,409,481.220637
# Hour change: 		-0.15%
# Day change: 		0.45%
# Week change: 		-5.4%
# Total supply: 		2,739,590,000
# Circulating supply: 	2,739,590,000
# Percentage of coins in circulation: 100
#
# 58: Bytecoin (BCN)
# Market cap: 		$8,184,545,232.0
# Price: 			$0.0444650744
# 24h Volume: 		$1,556,685.9985156283
# Hour change: 		5.73%
# Day change: 		-2.76%
# Week change: 		7.84%
# Total supply: 		184,066,828,814
# Circulating supply: 	184,066,828,814
# Percentage of coins in circulation: 100
#
# 59: DigiByte (DGB)
# Market cap: 		$8,116,298,560.0
# Price: 			$0.6682231356
# 24h Volume: 		$84,042,342.57617022
# Hour change: 		-1.07%
# Day change: 		-0.99%
# Week change: 		-5.87%
# Total supply: 		12,146,090,322
# Circulating supply: 	12,146,090,322
# Percentage of coins in circulation: 100
#
# 60: MonaCoin (MONA)
# Market cap: 		$8,058,264,465.0
# Price: 			$122.597053468
# 24h Volume: 		$139,670,014.70378712
# Hour change: 		-0.37%
# Day change: 		-1.16%
# Week change: 		-10.06%
# Total supply: 		65,729,675
# Circulating supply: 	65,729,675
# Percentage of coins in circulation: 100
#
# 61: Pundi X (NPXS)
# Market cap: 		$7,946,218,984.0
# Price: 			$0.0338178036
# 24h Volume: 		$123,568,833.9434301
# Hour change: 		-0.1%
# Day change: 		-1.09%
# Week change: 		-13.84%
# Total supply: 		261,834,927,333
# Circulating supply: 	234,971,468,515
# Percentage of coins in circulation: 89
#
# 62: Mixin (XIN)
# Market cap: 		$7,694,517,389.0
# Price: 			$16858.4633229791
# 24h Volume: 		$7,081,096.627309
# Hour change: 		-0.77%
# Day change: 		-3.48%
# Week change: 		6.23%
# Total supply: 		1,000,000
# Circulating supply: 	456,419
# Percentage of coins in circulation: 45
#
# 63: 0x (ZRX)
# Market cap: 		$7,532,777,191.0
# Price: 			$12.5464736602
# 24h Volume: 		$732,605,079.0007958
# Hour change: 		-0.22%
# Day change: 		-2.99%
# Week change: 		-11.89%
# Total supply: 		1,000,000,000
# Circulating supply: 	600,389,990
# Percentage of coins in circulation: 60
#
# 64: IOST (IOST)
# Market cap: 		$7,531,096,572.0
# Price: 			$0.6268618387
# 24h Volume: 		$1,469,872,805.2222526
# Hour change: 		-0.84%
# Day change: 		0.78%
# Week change: 		-11.46%
# Total supply: 		21,000,000,000
# Circulating supply: 	12,013,965,609
# Percentage of coins in circulation: 57
#
# 65: THETA (THETA)
# Market cap: 		$7,511,195,692.0
# Price: 			$8.6285726374
# 24h Volume: 		$112,762,009.53127673
# Hour change: 		-0.44%
# Day change: 		-3.25%
# Week change: 		-0.89%
# Total supply: 		1,000,000,000
# Circulating supply: 	870,502,690
# Percentage of coins in circulation: 87
#
# 66: Karatgold Coin (KBC)
# Market cap: 		$7,227,316,672.0
# Price: 			$1.7159477036
# 24h Volume: 		$209,724,675.4423927
# Hour change: 		-2.43%
# Day change: 		-2.71%
# Week change: 		-20.64%
# Total supply: 		12,000,000,000
# Circulating supply: 	4,211,851,362
# Percentage of coins in circulation: 35
#
# 67: ETERNAL TOKEN (XET)
# Market cap: 		$7,134,821,310.0
# Price: 			$76.332741095
# 24h Volume: 		$8,165,319.628766578
# Hour change: 		-0.88%
# Day change: 		-7.37%
# Week change: 		-22.67%
# Total supply: 		200,000,000
# Circulating supply: 	93,470,000
# Percentage of coins in circulation: 46
#
# 68: Insight Chain (INB)
# Market cap: 		$6,973,950,131.0
# Price: 			$19.9311132737
# 24h Volume: 		$410,041,549.5042731
# Hour change: 		-0.32%
# Day change: 		-2.14%
# Week change: 		-6.24%
# Total supply: 		10,000,000,000
# Circulating supply: 	349,902,689
# Percentage of coins in circulation: 3
#
# 69: Quant (QNT)
# Market cap: 		$6,964,270,597.0
# Price: 			$576.8592507307
# 24h Volume: 		$213,795,382.6122311
# Hour change: 		-0.57%
# Day change: 		-2.99%
# Week change: 		-13.46%
# Total supply: 		14,612,493
# Circulating supply: 	12,072,738
# Percentage of coins in circulation: 82
#
# 70: Komodo (KMD)
# Market cap: 		$6,958,133,782.0
# Price: 			$60.2714038766
# 24h Volume: 		$200,826,048.4260472
# Hour change: 		-0.26%
# Day change: 		-6.23%
# Week change: 		-5.09%
# Total supply: 		115,446,685
# Circulating supply: 	115,446,685
# Percentage of coins in circulation: 100
#
# 71: ICON (ICX)
# Market cap: 		$6,791,349,667.0
# Price: 			$13.8470872015
# 24h Volume: 		$704,206,495.354917
# Hour change: 		-1.09%
# Day change: 		-0.68%
# Week change: 		-16.88%
# Total supply: 		800,460,000
# Circulating supply: 	490,453,304
# Percentage of coins in circulation: 61
#
# 72: Siacoin (SC)
# Market cap: 		$6,765,234,454.0
# Price: 			$0.1617817334
# 24h Volume: 		$105,459,765.08492368
# Hour change: 		-1.11%
# Day change: 		-0.77%
# Week change: 		-9.68%
# Total supply: 		41,817,047,634
# Circulating supply: 	41,817,047,634
# Percentage of coins in circulation: 100
#
# 73: Bytom (BTM)
# Market cap: 		$6,614,511,366.0
# Price: 			$6.5980210965
# 24h Volume: 		$725,541,463.2342724
# Hour change: 		-0.5%
# Day change: 		-2.47%
# Week change: 		-16.38%
# Total supply: 		1,407,000,000
# Circulating supply: 	1,002,499,275
# Percentage of coins in circulation: 71
#
# 74: HyperCash (HC)
# Market cap: 		$6,516,935,429.0
# Price: 			$149.7121120279
# 24h Volume: 		$204,576,579.68185708
# Hour change: 		-0.05%
# Day change: 		-1.07%
# Week change: 		-7.83%
# Total supply: 		43,529,781
# Circulating supply: 	43,529,781
# Percentage of coins in circulation: 100
#
# 75: ABBC Coin (ABBC)
# Market cap: 		$5,976,482,610.0
# Price: 			$10.7818851195
# 24h Volume: 		$3,930,962,146.010084
# Hour change: 		-0.62%
# Day change: 		-14.96%
# Week change: 		-16.07%
# Total supply: 		1,002,169,590
# Circulating supply: 	554,307,762
# Percentage of coins in circulation: 55
#
# 76: Qubitica (QBIT)
# Market cap: 		$5,944,157,039.0
# Price: 			$2850.4823647279
# 24h Volume: 		$15,345,396.7396826
# Hour change: 		-0.48%
# Day change: 		-0.69%
# Week change: 		-8.8%
# Total supply: 		10,000,000
# Circulating supply: 	2,085,316
# Percentage of coins in circulation: 20
#
# 77: Nash Exchange (NEX)
# Market cap: 		$5,920,721,046.0
# Price: 			$163.5708405652
# 24h Volume: 		$103,772,515.44663961
# Hour change: 		-7.06%
# Day change: 		-8.13%
# Week change: 		-25.61%
# Total supply: 		56,296,100
# Circulating supply: 	36,196,678
# Percentage of coins in circulation: 64
#
# 78: Ren (REN)
# Market cap: 		$5,816,588,342.0
# Price: 			$7.3109922091
# 24h Volume: 		$327,626,344.95615804
# Hour change: 		-0.03%
# Day change: 		-5.37%
# Week change: 		-18.02%
# Total supply: 		1,000,000,000
# Circulating supply: 	795,594,931
# Percentage of coins in circulation: 79
#
# 79: Dai (DAI)
# Market cap: 		$5,633,441,225.0
# Price: 			$71.5172075663
# 24h Volume: 		$419,061,476.17490786
# Hour change: 		0.09%
# Day change: 		0.64%
# Week change: 		0.08%
# Total supply: 		78,770,430
# Circulating supply: 	78,770,430
# Percentage of coins in circulation: 100
#
# 80: NEXT (NET)
# Market cap: 		$5,621,766,564.0
# Price: 			$111.8330697871
# 24h Volume: 		$501,722,891.4986472
# Hour change: 		-0.66%
# Day change: 		3.02%
# Week change: 		17.09%
# Total supply: 		973,628,555
# Circulating supply: 	50,269,268
# Percentage of coins in circulation: 5
#
# 81: GXChain (GXC)
# Market cap: 		$5,523,403,665.0
# Price: 			$84.9754410055
# 24h Volume: 		$572,928,524.4004619
# Hour change: 		-1.01%
# Day change: 		-8.52%
# Week change: 		-31.33%
# Total supply: 		99,821,284
# Circulating supply: 	65,000,000
# Percentage of coins in circulation: 65
#
# 82: Verge (XVG)
# Market cap: 		$5,393,085,971.0
# Price: 			$0.339627675
# 24h Volume: 		$90,631,610.50399636
# Hour change: 		-1.7%
# Day change: 		-1.44%
# Week change: 		-14.05%
# Total supply: 		15,879,406,679
# Circulating supply: 	15,879,406,679
# Percentage of coins in circulation: 100
#
# 83: MaidSafeCoin (MAID)
# Market cap: 		$5,269,788,476.0
# Price: 			$11.6445926171
# 24h Volume: 		$30,722,345.64086486
# Hour change: 		-3.33%
# Day change: 		-9.48%
# Week change: 		-9.4%
# Total supply: 		452,552,412
# Circulating supply: 	452,552,412
# Percentage of coins in circulation: 100
#
# 84: Zilliqa (ZIL)
# Market cap: 		$5,241,120,398.0
# Price: 			$0.6033041526
# 24h Volume: 		$637,147,318.0182662
# Hour change: 		-1.21%
# Day change: 		-4.87%
# Week change: 		-7.87%
# Total supply: 		12,533,042,435
# Circulating supply: 	8,687,360,058
# Percentage of coins in circulation: 69
#
# 85: Aeternity (AE)
# Market cap: 		$5,232,073,047.0
# Price: 			$18.7725532789
# 24h Volume: 		$931,302,399.8321247
# Hour change: 		-0.29%
# Day change: 		-0.32%
# Week change: 		-8.77%
# Total supply: 		324,529,597
# Circulating supply: 	278,708,654
# Percentage of coins in circulation: 85
#
# 86: Flexacoin (FXC)
# Market cap: 		$4,979,522,206.0
# Price: 			$0.2456876335
# 24h Volume: 		$1,166,971.02699736
# Hour change: 		-0.45%
# Day change: 		-6.73%
# Week change: 		-8.74%
# Total supply: 		20,267,695,749
# Circulating supply: 	20,267,695,749
# Percentage of coins in circulation: 100
#
# 87: Status (SNT)
# Market cap: 		$4,789,612,899.0
# Price: 			$1.3800994881
# 24h Volume: 		$1,204,625,385.970445
# Hour change: 		-0.32%
# Day change: 		-3.17%
# Week change: 		-3.78%
# Total supply: 		6,804,870,174
# Circulating supply: 	3,470,483,788
# Percentage of coins in circulation: 50
#
# 88: Steem (STEEM)
# Market cap: 		$4,745,389,809.0
# Price: 			$13.937711111
# 24h Volume: 		$193,339,459.02784377
# Hour change: 		-0.75%
# Day change: 		4.33%
# Week change: 		-6.32%
# Total supply: 		357,445,336
# Circulating supply: 	340,471,242
# Percentage of coins in circulation: 95
#
# 89: ZB (ZB)
# Market cap: 		$4,689,313,907.0
# Price: 			$28.7337506151
# 24h Volume: 		$4,895,137,546.496569
# Hour change: 		-0.93%
# Day change: 		-1.44%
# Week change: 		11.89%
# Total supply: 		2,100,000,000
# Circulating supply: 	163,198,810
# Percentage of coins in circulation: 7
# 90: Waltonchain (WTC)
# Market cap: 		$4,513,707,212.0
# Price: 			$107.0944844848
# 24h Volume: 		$215,796,785.56287837
# Hour change: 		0.47%
# Day change: 		-1.8%
# Week change: 		-8.05%
# Total supply: 		70,000,000
# Circulating supply: 	42,146,962
# Percentage of coins in circulation: 60
#
# 91: Metaverse ETP (ETP)
# Market cap: 		$4,473,654,914.0
# Price: 			$61.6504879985
# 24h Volume: 		$356,530,111.0468988
# Hour change: 		-0.19%
# Day change: 		0.22%
# Week change: 		4.04%
# Total supply: 		76,338,648
# Circulating supply: 	72,564,793
# Percentage of coins in circulation: 95
#
# 92: Bitbook Gambling (BXK)
# Market cap: 		$4,370,959,004.0
# Price: 			$11.8651124309
# 24h Volume: 		$52,397,896.52902807
# Hour change: 		-3.12%
# Day change: 		-3.54%
# Week change: 		-9.31%
# Total supply: 		741,456,054
# Circulating supply: 	368,387,491
# Percentage of coins in circulation: 49
#
# 93: Zcoin (XZC)
# Market cap: 		$4,298,339,623.0
# Price: 			$527.5173370478
# 24h Volume: 		$117,684,433.14564012
# Hour change: 		-0.2%
# Day change: 		-1.38%
# Week change: 		-9.75%
# Total supply: 		21,400,000
# Circulating supply: 	8,148,243
# Percentage of coins in circulation: 38
#
# 94: RIF Token (RIF)
# Market cap: 		$4,283,309,275.0
# Price: 			$8.9612550739
# 24h Volume: 		$34,269,474.76209787
# Hour change: 		-1.91%
# Day change: 		-3.6%
# Week change: 		-10.61%
# Total supply: 		1,000,000,000
# Circulating supply: 	477,980,957
# Percentage of coins in circulation: 47
#
# 95: 1irstcoin (FST)
# Market cap: 		$4,161,595,913.0
# Price: 			$188.4354047183
# 24h Volume: 		$11,393,573.204806529
# Hour change: 		-0.83%
# Day change: 		3.49%
# Week change: 		-61.1%
# Total supply: 		100,000,000
# Circulating supply: 	22,085,000
# Percentage of coins in circulation: 22
#
# 96: Japan Content Token (JCT)
# Market cap: 		$4,139,621,428.0
# Price: 			$14.1211338224
# 24h Volume: 		$29,270,990.516438376
# Hour change: 		-1.28%
# Day change: 		3.78%
# Week change: 		-15.29%
# Total supply: 		2,500,000,000
# Circulating supply: 	293,150,782
# Percentage of coins in circulation: 11
#
# 97: Crypto.com (MCO)
# Market cap: 		$4,034,326,172.0
# Price: 			$255.4368314922
# 24h Volume: 		$279,040,484.6434536
# Hour change: 		-1.09%
# Day change: 		-3.12%
# Week change: 		-10.18%
# Total supply: 		31,587,682
# Circulating supply: 	15,793,831
# Percentage of coins in circulation: 49
#
# 98: Ardor (ARDR)
# Market cap: 		$4,004,777,087.0
# Price: 			$4.0087878995
# 24h Volume: 		$44,113,168.78925208
# Hour change: 		-0.88%
# Day change: 		-2.83%
# Week change: 		-10.74%
# Total supply: 		998,999,495
# Circulating supply: 	998,999,495
# Percentage of coins in circulation: 100
#
# 99: WAX (WAX)
# Market cap: 		$4,003,444,806.0
# Price: 			$4.2462376169
# 24h Volume: 		$32,074,186.958638664
# Hour change: 		0.06%
# Day change: 		-5.66%
# Week change: 		1.98%
# Total supply: 		1,850,000,000
# Circulating supply: 	942,821,662
# Percentage of coins in circulation: 50
#
# 100: Maximine Coin (MXM)
# Market cap: 		$3,740,400,192.0
# Price: 			$2.268283925
# 24h Volume: 		$219,552,467.80005524
# Hour change: 		0.9%
# Day change: 		3.02%
# Week change: 		-1.9%
# Total supply: 		16,000,000,000
# Circulating supply: 	1,649,000,000
# Percentage of coins in circulation: 10
#
# 101: Golem (GNT)
# Market cap: 		$3,727,621,235.0
# Price: 			$3.8650227956
# 24h Volume: 		$57,444,009.865296334
# Hour change: 		-1.16%
# Day change: 		-2.67%
# Week change: 		-3.31%
# Total supply: 		1,000,000,000
# Circulating supply: 	964,450,000
# Percentage of coins in circulation: 96
#
# 102: Clipper Coin (CCCX)
# Market cap: 		$3,703,639,702.0
# Price: 			$0.9809482341
# 24h Volume: 		$955,198.2275273276
# Hour change: 		1.38%
# Day change: 		-4.17%
# Week change: 		3.16%
# Total supply: 		5,000,000,000
# Circulating supply: 	3,775,570,996
# Percentage of coins in circulation: 75
#
# Again? (y/n): n
